# %%
print(45)
# Out:
# 45

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('doctor_availability.csv')
df.head(5)
# Out:
#           date_slot   specialization doctor_name  is_available  \
# 0  05-08-2024 08:00  general_dentist    john doe          True
# 1  05-08-2024 08:30  general_dentist    john doe         False
# 2  05-08-2024 09:00  general_dentist    john doe         False
# 3  05-08-2024 09:30  general_dentist    john doe         False
# 4  05-08-2024 10:00  general_dentist    john doe         False
#
#    patient_to_attend
# 0                NaN
# 1          1000082.0
# 2          1000048.0
# 3          1000036.0
# 4          1000024.0

# %%
df["date_slot"] = df["date_slot"].str.replace("2024", "2026", regex=False)

# %%
df.head()
# Out:
#           date_slot   specialization doctor_name  is_available  \
# 0  05-08-2026 08:00  general_dentist    john doe          True
# 1  05-08-2026 08:30  general_dentist    john doe         False
# 2  05-08-2026 09:00  general_dentist    john doe         False
# 3  05-08-2026 09:30  general_dentist    john doe         False
# 4  05-08-2026 10:00  general_dentist    john doe         False
#
#    patient_to_attend
# 0                NaN
# 1          1000082.0
# 2          1000048.0
# 3          1000036.0
# 4          1000024.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4280 entries, 0 to 4279
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   date_slot          4280 non-null   object
#  1   specialization     4280 non-null   object
#  2   doctor_name        4280 non-null   object
#  3   is_available       4280 non-null   bool
#  4   patient_to_attend  1564 non-null   float64
# dtypes: bool(1), float64(1), object(3)
# memory usage: 138.1+ KB

# %%
sum(df['date_slot'].isnull())
# Out:
# 0

# %%
print(df["date_slot"].head(10).tolist())
# Out:
# ['05-08-2026 08:00', '05-08-2026 08:30', '05-08-2026 09:00', '05-08-2026 09:30', '05-08-2026 10:00', '05-08-2026 10:30', '05-08-2026 11:00', '05-08-2026 11:30', '05-08-2026 12:00', '05-08-2026 12:30']

# %%
df["patient_to_attend"] = df["patient_to_attend"].astype("Int64")

# %%
df['date_slot'].head()
# Out:
# 0    05-08-2026 08:00
# 1    05-08-2026 08:30
# 2    05-08-2026 09:00
# 3    05-08-2026 09:30
# 4    05-08-2026 10:00
# Name: date_slot, dtype: object

# %%
import pandas as pd

# Parse DD-MM-YYYY HH:MM
df["date_slot"] = pd.to_datetime(
    df["date_slot"],
    format="%d-%m-%Y %H:%M"
)

# %%
df['date_slot'].head()
# Out:
# 0   2026-08-05 08:00:00
# 1   2026-08-05 08:30:00
# 2   2026-08-05 09:00:00
# 3   2026-08-05 09:30:00
# 4   2026-08-05 10:00:00
# Name: date_slot, dtype: datetime64[ns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4280 entries, 0 to 4279
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   date_slot          4280 non-null   datetime64[us]
#  1   specialization     4280 non-null   str
#  2   doctor_name        4280 non-null   str
#  3   is_available       4280 non-null   bool
#  4   patient_to_attend  1564 non-null   Int64
# dtypes: Int64(1), bool(1), datetime64[us](1), str(2)
# memory usage: 142.2 KB

# %%
df.isnull().sum()
# Out:
# date_slot               0
# specialization          0
# doctor_name             0
# is_available            0
# patient_to_attend    2716
# dtype: int64

# %%
df.head()
# Out:
#             date_slot   specialization doctor_name  is_available  \
# 0 2026-08-05 08:00:00  general_dentist    john doe          True
# 1 2026-08-05 08:30:00  general_dentist    john doe         False
# 2 2026-08-05 09:00:00  general_dentist    john doe         False
# 3 2026-08-05 09:30:00  general_dentist    john doe         False
# 4 2026-08-05 10:00:00  general_dentist    john doe         False
#
#    patient_to_attend
# 0               <NA>
# 1            1000082
# 2            1000048
# 3            1000036
# 4            1000024

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4280 entries, 0 to 4279
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   date_slot          4280 non-null   datetime64[ns]
#  1   specialization     4280 non-null   object
#  2   doctor_name        4280 non-null   object
#  3   is_available       4280 non-null   bool
#  4   patient_to_attend  1564 non-null   Int64
# dtypes: Int64(1), bool(1), datetime64[ns](1), object(2)
# memory usage: 142.2+ KB

# %%
df.to_csv('doctor_availability_cleaned.csv', index=False)
